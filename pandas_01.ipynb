# %% [markdown]
#  pandas work
# * basics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %%
df = pd.read_csv("C:\\Users\\aalgo\\Downloads\\archive_(4)\\Amazon_Sale_Report.csv" )
# Out:
# C:\Users\aalgo\AppData\Local\Temp\ipykernel_27136\2823534796.py:1: DtypeWarning: Columns (0: Unnamed: 22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:\\Users\\aalgo\\Downloads\\archive_(4)\\Amazon_Sale_Report.csv" )

# %%
df.head(3)
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
#
#   Category  ... currency  Amount    ship-city   ship-state ship-postal-code  \
# 0      Set  ...      INR  647.62       MUMBAI  MAHARASHTRA         400081.0
# 1    kurta  ...      INR  406.00    BENGALURU    KARNATAKA         560085.0
# 2    kurta  ...      INR  329.00  NAVI MUMBAI  MAHARASHTRA         410210.0
#
#    ship-country                                      promotion-ids    B2B  \
# ...

# %%
df.set_index("index", inplace=True)

# %%
df.head(3)
# Out:
#                   Order ID      Date                        Status Fulfilment  \
# index
# 0      405-8078784-5731545  04-30-22                     Cancelled   Merchant
# 1      171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer   Merchant
# 2      404-0687676-7273146  04-30-22                       Shipped     Amazon
#
#       Sales Channel  ship-service-level    Style              SKU Category  \
# index
# 0          Amazon.in           Standard   SET389   SET389-KR-NP-S      Set
# 1          Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL    kurta
# 2          Amazon.in          Expedited  JNE3371    JNE3371-KR-XL    kurta
#
#       Size  ... currency  Amount    ship-city   ship-state  ship-postal-code  \
# index       ...
# 0        S  ...      INR  647.62       MUMBAI  MAHARASHTRA          400081.0
# 1      3XL  ...      INR  406.00    BENGALURU    KARNATAKA          560085.0
# 2       XL  ...      INR  329.00  NAVI MUMBAI  MAHARASHTRA          410210.0
#
# ...

# %% [markdown]
# * Selecting rows and columns

# %%
df['Order ID']
# Out:
# index
# 0         405-8078784-5731545
# 1         171-9198151-1101146
# 2         404-0687676-7273146
# 3         403-9615377-8133951
# 4         407-1069790-7240320
#                  ...
# 128970    406-6001380-7673107
# 128971    402-9551604-7544318
# 128972    407-9547469-3152358
# 128973    402-6184140-0545956
# 128974    408-7436540-8728312
# Name: Order ID, Length: 128975, dtype: str

# %%
df.iloc[0,1:8]
# Out:
# Date                        04-30-22
# Status                     Cancelled
# Fulfilment                  Merchant
# Sales Channel              Amazon.in
# ship-service-level          Standard
# Style                         SET389
# SKU                   SET389-KR-NP-S
# Name: 0, dtype: object

# %% [markdown]
# * Conditions to filter rows and columns

# %%
df.rename(columns={'Sales Channel':'Sales_Channel'}, inplace=True)

# %%
df.columns = df.columns.str.replace(' ', '_')

# %%
df['ship-service-level']=='Standard'
# Out:
# index
# 0          True
# 1          True
# 2         False
# 3          True
# 4         False
#           ...
# 128970    False
# 128971    False
# 128972    False
# 128973    False
# 128974    False
# Name: ship-service-level, Length: 128975, dtype: bool

# %%
filt = df['ship-service-level']=='Standard'
df[filt]
# Out:
#                    Order_ID      Date                        Status  \
# index
# 0       405-8078784-5731545  04-30-22                     Cancelled
# 1       171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 3       403-9615377-8133951  04-30-22                     Cancelled
# 7       406-7807733-3785945  04-30-22  Shipped - Delivered to Buyer
# 12      405-5513694-8146768  04-30-22  Shipped - Delivered to Buyer
# ...                     ...       ...                           ...
# 128874  405-4724097-1016369  06-01-22  Shipped - Delivered to Buyer
# 128875  403-9524128-9243508  06-01-22                     Cancelled
# 128887  405-6493630-8542756  05-31-22  Shipped - Delivered to Buyer
# 128890  407-0116398-1810752  05-31-22                     Cancelled
# 128891  403-0317423-9322704  05-31-22  Shipped - Delivered to Buyer
#
#        Fulfilment Sales_Channel_ ship-service-level    Style              SKU  \
# index
# ...

# %%
df.loc[filt, 'Sales_Channel_']
# Out:
# index
# 0         Amazon.in
# 1         Amazon.in
# 3         Amazon.in
# 7         Amazon.in
# 12        Amazon.in
#             ...
# 128874    Amazon.in
# 128875    Amazon.in
# 128887    Amazon.in
# 128890    Amazon.in
# 128891    Amazon.in
# Name: Sales_Channel_, Length: 40360, dtype: str

# %% [markdown]
# * Data Wrangling

# %%
mean =df["Amount"].mean()

# %%
df["Amount"].replace(np.nan, mean)
df
# Out:
#                    Order_ID      Date                        Status  \
# index
# 0       405-8078784-5731545  04-30-22                     Cancelled
# 1       171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2       404-0687676-7273146  04-30-22                       Shipped
# 3       403-9615377-8133951  04-30-22                     Cancelled
# 4       407-1069790-7240320  04-30-22                       Shipped
# ...                     ...       ...                           ...
# 128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  408-7436540-8728312  05-31-22                       Shipped
#
#        Fulfilment Sales_Channel_ ship-service-level    Style              SKU  \
# index
# ...

# %% [markdown]
# * Data Formating

# %%
df["Amount"] = 92*df["Amount"]

# %%
df.rename(columns={'$Amount':'Amount'}, inplace=True)

# %%
df.head(5)
# Out:
#                   Order_ID      Date                        Status Fulfilment  \
# index
# 0      405-8078784-5731545  04-30-22                     Cancelled   Merchant
# 1      171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer   Merchant
# 2      404-0687676-7273146  04-30-22                       Shipped     Amazon
# 3      403-9615377-8133951  04-30-22                     Cancelled   Merchant
# 4      407-1069790-7240320  04-30-22                       Shipped     Amazon
#
#       Sales_Channel_ ship-service-level    Style              SKU  \
# index
# 0          Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1          Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2          Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3          Amazon.in           Standard    J0341       J0341-DR-L
# 4          Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#             Category Size  ... currency    Amount    ship-city   ship-state  \
# ...

# %% [markdown]
# * Data Normalisation

# %%
df['Amount'].dtype
# Out:
# dtype('float64')

# %%
df['Amount'] = pd.to_numeric(df['Amount'], errors='coerce')

# %%
df['Amount'].isna().sum()
# Out:
# np.int64(7795)

# %%
df['Amount'] .fillna(df['Amount'].mean(), inplace=True)
# Out:
# C:\Users\aalgo\AppData\Local\Temp\ipykernel_27136\3484050870.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Amount'] .fillna(df['Amount'].mean(), inplace=True)
# index
# 0          59581.04
# 1          37352.00
# 2          30268.00
# 3          69306.36
# 4          52808.00
#             ...
# ...

# %%
(df['Amount'].isna().sum())
# Out:
# np.int64(7795)

# %%
df.head(5)
# Out:
#                   Order_ID      Date                        Status Fulfilment  \
# index
# 0      405-8078784-5731545  04-30-22                     Cancelled   Merchant
# 1      171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer   Merchant
# 2      404-0687676-7273146  04-30-22                       Shipped     Amazon
# 3      403-9615377-8133951  04-30-22                     Cancelled   Merchant
# 4      407-1069790-7240320  04-30-22                       Shipped     Amazon
#
#       Sales_Channel_ ship-service-level    Style              SKU  \
# index
# 0          Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1          Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2          Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3          Amazon.in           Standard    J0341       J0341-DR-L
# 4          Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#             Category Size  ... currency    Amount    ship-city   ship-state  \
# ...

# %%
mean_amount = df['Amount'].mean()
df['Amount'].fillna(mean_amount, inplace=True)
# Out:
# C:\Users\aalgo\AppData\Local\Temp\ipykernel_27136\2337150416.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Amount'].fillna(mean_amount, inplace=True)
# index
# 0          59581.04
# 1          37352.00
# 2          30268.00
# 3          69306.36
# 4          52808.00
#             ...
# 128970     47564.00
# ...

# %%
df['Amount'].isna().sum()
# Out:
# np.int64(7795)

# %%
df['Amount'] = (df['Amount']- df['Amount'].mean())/ df['Amount'].std()

# %% [markdown]
# * Exploratory Data Analysis

# %%
sns.boxplot(x="Category", y="Amount",data=df)
# Out:
# <Axes: xlabel='Category', ylabel='Amount'>

# %%
y =["Amouny"]
x =["Category"]
plt.scatter(x,y)
plt.title("scatter_of_amount_per_category")
plt.xlabel("per_cate")
plt.ylabel("per_amount")
# Out:
# Text(0, 0.5, 'per_amount')

# %%
df_test = df[['ship-city','Category','Amount']]
df_grp = df_test.groupby(['ship-city','Category'], as_index=False).mean()
df_grp
# Out:
#                                             ship-city       Category    Amount
# 0      (Chikmagalur disterict).     (N.R pur thaluku)          kurta -0.923011
# 1                      (Via Cuncolim)Quepem,South Goa            Set  1.829364
# 2                                          ,HYDERABAD            Set -0.304260
# 3                  ,raibarely road faizabad (Ayodhya)            Set  1.683566
# 4                                             ..katra            Set -0.026889
# ...                                               ...            ...       ...
# 15189                                        yavatmal  Western Dress  0.307379
# 15190                                          yazali            Top -0.574519
# 15191                                        yellapur            Set  0.623866
# 15192                                        zirakpur            Set  0.723436
# 15193                                            लखनऊ            Set  1.255064
#
# ...

# %%
df_pivot = df_grp.pivot(index='Category' , columns='ship-city')

# %%
plt.pcolor(df_pivot, cmap='RdBu')
plt.colorbar()
plt.show()

# %%
df.iloc[2]
# Out:
# Order_ID                                       404-0687676-7273146
# Date                                                      04-30-22
# Status                                                     Shipped
# Fulfilment                                                  Amazon
# Sales_Channel_                                           Amazon.in
# ship-service-level                                       Expedited
# Style                                                      JNE3371
# SKU                                                  JNE3371-KR-XL
# Category                                                     kurta
# Size                                                            XL
# ASIN                                                    B07WV4JV4D
# Courier_Status                                             Shipped
# Qty                                                              1
# currency                                                       INR
# ...

# %%
df.head(3)
# Out:
#                   Order_ID      Date                        Status Fulfilment  \
# index
# 0      405-8078784-5731545  04-30-22                     Cancelled   Merchant
# 1      171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer   Merchant
# 2      404-0687676-7273146  04-30-22                       Shipped     Amazon
#
#       Sales_Channel_ ship-service-level    Style              SKU Category  \
# index
# 0          Amazon.in           Standard   SET389   SET389-KR-NP-S      Set
# 1          Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL    kurta
# 2          Amazon.in          Expedited  JNE3371    JNE3371-KR-XL    kurta
#
#       Size  ... currency    Amount    ship-city   ship-state  \
# index       ...
# 0        S  ...      INR -0.003348       MUMBAI  MAHARASHTRA
# 1      3XL  ...      INR -0.862558    BENGALURU    KARNATAKA
# 2       XL  ...      INR -1.136373  NAVI MUMBAI  MAHARASHTRA
#
#        ship-postal-code ship-country  \
# index
# ...

# %% [markdown]
# * Data Updating

# %%
df.loc[2, ['Status', 'Courier_Status']] = ['Shipped', 'shipped']
df.loc[2, ['Status', 'Courier_Status']]
# Out:
# Status            Shipped
# Courier_Status    shipped
# Name: 2, dtype: str

# %% [markdown]
# * Regression Intro

# %%
df.head()
# Out:
#                   Order_ID      Date                        Status Fulfilment  \
# index
# 0      405-8078784-5731545  04-30-22                     Cancelled   Merchant
# 1      171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer   Merchant
# 2      404-0687676-7273146  04-30-22                       Shipped     Amazon
# 3      403-9615377-8133951  04-30-22                     Cancelled   Merchant
# 4      407-1069790-7240320  04-30-22                       Shipped     Amazon
#
#       Sales_Channel_ ship-service-level    Style              SKU  \
# index
# 0          Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1          Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2          Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3          Amazon.in           Standard    J0341       J0341-DR-L
# 4          Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#             Category Size  ... currency    Amount    ship-city   ship-state  \
# ...

# %%
import seaborn as sns

# %%
ax1 = sns.kdeplot(data = df['Amount'], color= "r", label = "Amount")
ax1.set_title("Distribution of Amount")
ax1.set_xlabel("Amount")
ax1.set_ylabel("Density")
ax1.legend()

# %%
sns.boxplot(x="Category", y="Amount",data=df)
# Out:
# <Axes: xlabel='Category', ylabel='Amount'>

# %%
sns.catplot(x="Category", y="Amount", data=df, kind="boxen")

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=df['Category'], y=df['Amount'])
plt.title("scatter_of_amount_per_category")
# Out:
# Text(0.5, 1.0, 'scatter_of_amount_per_category')
